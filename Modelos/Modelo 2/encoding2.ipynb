# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Otros objetivos
# -----------------------------------------------------------------------
import math

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

import os
import sys 

import warnings
warnings.filterwarnings("ignore")



# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestRegressor
from scipy import stats

import pickle
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, RobustScaler


pd.options.display.float_format = "{:,.2f}".format 

# import plotly_express as px


# Métodos estadísticos
# -----------------------------------------------------------------------
from scipy.stats import zscore # para calcular el z-score
from sklearn.neighbors import LocalOutlierFactor # para detectar outliers usando el método LOF
from sklearn.ensemble import IsolationForest # para detectar outliers usando el metodo IF
from sklearn.neighbors import NearestNeighbors # para calcular la epsilon

# Para generar combinaciones de listas
# -----------------------------------------------------------------------
from itertools import product, combinations


from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Para la codificación de las variables numéricas
# -----------------------------------------------------------------------
from sklearn.preprocessing import OneHotEncoder #, TargetEncoder # para poder aplicar los métodos de OneHot, Ordinal,  Label y Target Encoder 

sys.path.append(os.path.abspath("../../src"))   
import Soporte_encoding as f
import Soporte_preprocesamiento as b

from sklearn.model_selection import train_test_split
from category_encoders import TargetEncoder     #solo me deja hacerlo si uso el entorno default en vez del proyecto
pd.set_option("display.max_columns", None)

# %%
df_sinull=pd.read_pickle("../../datos/datos2/datos_sin_nulos.pkl").reset_index(drop=True)

# %%
df_sinull.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 0 51.00       0.00      Travel_Rarely                   Sales
# 1 31.00       1.00  Travel_Frequently  Research & Development
# 2 32.00       0.00  Travel_Frequently  Research & Development
# 3 38.00       0.00         Non-Travel  Research & Development
# 4 32.00       0.00      Travel_Rarely  Research & Development
#
#   DistanceFromHome      Education EducationField  Gender JobLevel  \
# 0      entre 5 y 8        College  Life Sciences  Female   Intern
# 1     entre 9 y 12  Below College  Life Sciences  Female   Intern
# 2    entre 13 y 18         Master          Other    Male  Manager
# 3      entre 1 y 4         Doctor  Life Sciences    Male   Senior
# 4     entre 9 y 12  Below College        Medical    Male   Intern
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married       1,482.11                   1
# 1         Research Scientist        Single         473.36                   0
# 2            Sales Executive       Married       2,184.06                   1
# 3            Human Resources       Married         940.27                   3
# 4            Sales Executive        Single         264.65                   4
#
#    PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 0              11.00              Bad                  1
# 1              23.00             Good                  6
# 2              15.00             Best                  5
# 3              11.00             Best                 13
# 4              12.00           Better                  9
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                  6.00            1.00                     0.00
# 1                  3.00            5.00                     1.00
# 2                  2.00            5.00                     0.00
# 3                  5.00            8.00                     7.00
# 4                  2.00            6.00                     0.00
#
#   EnvironmentSatisfaction JobSatisfaction WorkLifeBalance JobInvolvement
# 0                    High       Very High            Good           High
# 1                    High          Medium            Best         Medium
# 2                  Medium          Medium             Bad           High
# 3               Very High       Very High          Better         Medium
# 4               Very High             Low          Better           High

# %%
df_sinull_copy=df_sinull.copy()

# %%
df_sinull_copy["TotalWorkingYears"]=df_sinull_copy["TotalWorkingYears"].astype("category")
df_sinull_copy["NumCompaniesWorked"]=df_sinull_copy["NumCompaniesWorked"].astype("category")

# %%
df_categoricas= df_sinull_copy.select_dtypes(include=["category","object"])

# %%
df_categoricas.head()
# Out:
#       BusinessTravel              Department DistanceFromHome      Education  \
# 0      Travel_Rarely                   Sales      entre 5 y 8        College
# 1  Travel_Frequently  Research & Development     entre 9 y 12  Below College
# 2  Travel_Frequently  Research & Development    entre 13 y 18         Master
# 3         Non-Travel  Research & Development      entre 1 y 4         Doctor
# 4      Travel_Rarely  Research & Development     entre 9 y 12  Below College
#
#   EducationField  Gender JobLevel                    JobRole MaritalStatus  \
# 0  Life Sciences  Female   Intern  Healthcare Representative       Married
# 1  Life Sciences  Female   Intern         Research Scientist        Single
# 2          Other    Male  Manager            Sales Executive       Married
# 3  Life Sciences    Male   Senior            Human Resources       Married
# 4        Medical    Male   Intern            Sales Executive        Single
#
#   NumCompaniesWorked StockOptionLevel TotalWorkingYears TrainingTimesLastYear  \
# 0                  1              Bad                 1                  6.00
# 1                  0             Good                 6                  3.00
# 2                  1             Best                 5                  2.00
# 3                  3             Best                13                  5.00
# 4                  4           Better                 9                  2.00
#
#   EnvironmentSatisfaction JobSatisfaction WorkLifeBalance JobInvolvement
# 0                    High       Very High            Good           High
# 1                    High          Medium            Best         Medium
# 2                  Medium          Medium             Bad           High
# 3               Very High       Very High          Better         Medium
# 4               Very High             Low          Better           High

# %% [markdown]
# Tenemos 17 columnas de categóricas

# %%
df_categoricas.nunique()
# Out:
# BusinessTravel              3
# Department                  3
# DistanceFromHome            6
# Education                   5
# EducationField              6
# Gender                      2
# JobLevel                    5
# JobRole                     9
# MaritalStatus               3
# NumCompaniesWorked         10
# StockOptionLevel            4
# TotalWorkingYears          40
# TrainingTimesLastYear       7
# EnvironmentSatisfaction     4
# JobSatisfaction             4
# WorkLifeBalance             4
# JobInvolvement              4
# dtype: int64

# %% [markdown]
# Ahora debemos comprobar la normalidad y homocedasticidad para saber si son parametricas o no parametricas (Con el fin de más adelante poder evaluar si hay diferencias significativas)

# %% [markdown]
# Tuve que convertir estas variables a str porque sino no las detectaba como categóricas

# %%
# df_sinout_copy["exterior"]=df_sinout_copy["exterior"].astype(str)
# df_sinout_copy["rooms"]=df_sinout_copy["rooms"].astype(str)
# df_sinout_copy["bathrooms"]=df_sinout_copy["bathrooms"].astype(str)

# %%
f.detectar_orden_cat(df_sinull_copy,df_categoricas.columns,"Attrition")
# Out:
# Estamos evaluando el orden de la variable BUSINESSTRAVEL
# Attrition          0.00  1.00
# BusinessTravel
# Non-Travel          147    12
# Travel_Frequently   220    77
# Travel_Rarely       954   163
# La variable BusinessTravel SI tiene orden
# Estamos evaluando el orden de la variable DEPARTMENT
# Attrition               0.00  1.00
# Department
# Human Resources           44    22
# Research & Development   870   160
# Sales                    407    70
# La variable Department SI tiene orden
# Estamos evaluando el orden de la variable DISTANCEFROMHOME
# Attrition         0.00  1.00
# DistanceFromHome
# entre 1 y 4        515    99
# entre 13 y 18      122    29
# entre 19 y 23      103    18
# entre 24 y 29      132    18
# entre 5 y 8        265    45
# entre 9 y 12       184    43
# La variable DistanceFromHome NO tiene orden
# Estamos evaluando el orden de la variable EDUCATION
# Attrition      0.00  1.00
# Education
# Below College   154    27
# College         246    57
# Bachelor        519    96
# Master          358    64
# Doctor           44     8
# La variable Education NO tiene orden
# Estamos evaluando el orden de la variable EDUCATIONFIELD
# Attrition         0.00  1.00
# EducationField
# Human Resources     16    12
# Life Sciences      547   108
# Marketing          141    26
# Medical            408    81
# Other               80    10
# Technical Degree   129    15
# La variable EducationField SI tiene orden
# Estamos evaluando el orden de la variable GENDER
# Attrition  0.00  1.00
# Gender
# Female      525    95
# Male        796   157
# La variable Gender NO tiene orden
# Estamos evaluando el orden de la variable JOBLEVEL
# Attrition  0.00  1.00
# JobLevel
# Intern      500    87
# Junior      467   104
# Senior      197    32
# Manager      94    17
# Head         63    12
# La variable JobLevel NO tiene orden
# Estamos evaluando el orden de la variable JOBROLE
# Attrition                  0.00  1.00
# JobRole
# Healthcare Representative   124    21
# Human Resources              47     7
# Laboratory Technician       232    46
# Manager                      91    16
# Manufacturing Director      141    16
# Research Director            63    22
# Research Scientist          254    54
# Sales Executive             290    58
# Sales Representative         79    12
# La variable JobRole NO tiene orden
# Estamos evaluando el orden de la variable MARITALSTATUS
# Attrition      0.00  1.00
# MaritalStatus
# Divorced        320    37
# Married         635    85
# Single          366   130
# La variable MaritalStatus SI tiene orden
# Estamos evaluando el orden de la variable NUMCOMPANIESWORKED
# Attrition           0.00  1.00
# NumCompaniesWorked
# 0                    188    25
# 1                    443   103
# 2                    142    17
# 3                    157    18
# 4                    132    19
# 5                     49    17
# 6                     57    18
# 7                     62    17
# 8                     49     6
# 9                     42    12
# La variable NumCompaniesWorked SI tiene orden
# Estamos evaluando el orden de la variable STOCKOPTIONLEVEL
# Attrition         0.00  1.00
# StockOptionLevel
# Bad                564   112
# Good               544    97
# Better             138    28
# Best                75    15
# La variable StockOptionLevel NO tiene orden
# Estamos evaluando el orden de la variable TOTALWORKINGYEARS
# Attrition          0.00  1.00
# TotalWorkingYears
# 0                     7     6
# 1                    43    41
# 2                    22     9
# 3                    36     9
# 4                    55    12
# 5                    80    17
# 6                   108    24
# 7                    68    22
# 8                    94    17
# 9                    93    12
# 10                  191    27
# 11                   31     7
# 12                   45     6
# 13                   34     3
# 14                   31     4
# 15                   37     5
# 16                   38     3
# 17                   30     3
# 18                   24     4
# 19                   20     3
# 20                   30     2
# 21                   36     1
# 22                   22     2
# 23                   20     2
# 24                   15     3
# 25                   14     1
# 26                   15     1
# 27                    8     0
# 28                   14     1
# 29                   10     0
# 30                    7     0
# 31                    8     1
# 32                   10     0
# 33                    6     1
# 34                    5     1
# 35                    3     0
# 36                    6     0
# 37                    4     0
# 38                    1     0
# 40                    0     2
# La variable TotalWorkingYears SI tiene orden
# Estamos evaluando el orden de la variable TRAININGTIMESLASTYEAR
# Attrition              0.00  1.00
# TrainingTimesLastYear
# 0.00                     45    10
# 1.00                     64    11
# 2.00                    486   103
# 3.00                    432    90
# 4.00                    116    17
# 5.00                    112    17
# 6.00                     66     4
# La variable TrainingTimesLastYear NO tiene orden
# Estamos evaluando el orden de la variable ENVIRONMENTSATISFACTION
# Attrition                0.00  1.00
# EnvironmentSatisfaction
# High                      429    68
# Low                       226    74
# Medium                    262    48
# Very High                 404    62
# La variable EnvironmentSatisfaction SI tiene orden
# Estamos evaluando el orden de la variable JOBSATISFACTION
# Attrition        0.00  1.00
# JobSatisfaction
# High              398    78
# Low               232    69
# Medium            255    50
# Very High         436    55
# La variable JobSatisfaction SI tiene orden
# Estamos evaluando el orden de la variable WORKLIFEBALANCE
# Attrition        0.00  1.00
# WorkLifeBalance
# Bad                56    27
# Best              129    28
# Better            834   136
# Good              302    61
# La variable WorkLifeBalance SI tiene orden
# Estamos evaluando el orden de la variable JOBINVOLVEMENT
# Attrition       0.00  1.00
# JobInvolvement
# Low               71    19
# Medium           333    62
# High             789   144
# Very High        128    27
# La variable JobInvolvement NO tiene orden

# %% [markdown]
# #### CONCLUSIONES SOBRE EL ORDEN:
#
# **NO ORDENADAS:**
# - Gender
# - DistanceFromHome
# - Education
# - JobLevel
# - StockOptionLevel
# - JobInvolvement a
# - TrainingTimesLastYear a
# - JobRole  a
#
#  *- get- dummies (pandas)*
#  *- One-Hot Encoding (SKlearn) (es más efectivo)*
#  *Ambas te crean tantas columnas como categorias hay en la columna y hace que en esa solo valga 1 las que coincidan y 0 el resto*
#
#
# **ORDENADAS:**
# - BusinessTravel
# - Department
# - MaritalStatus
# - NumCompaniesWorked
# - EnvironmentSatisfaction
# - JobSatisfaction
# - WorkLifeBalance
# - EducationField
# - TotalWorkingYears
#
#
# *lo de entre parentesis hace referencia a la cantidad de categorías que son diferentes en esa columna*
#
# *- Ordinal Encoding  (Los codifica en función de los pesos que le digamos)*
# *- Label Encoding (Los codifica en orden alfabetico)*
# *- Target Encoding (Los codifica en funcion de las medias (osea en función de la relación con la variable dependiente))*
# *- Frequency Encoding (Los codifica en funcion de la frecuencia(en función del value_counts))*

# %% [markdown]
# **Ahora pasamos al encodin de las que no tienen orden:**

# %%
df_sinull_copy.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'Gender', 'JobLevel', 'JobRole',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement'],
#       dtype='object')

# %%
diccionario_encoding = {"onehot": ["Gender", "DistanceFromHome", "Education", "JobLevel", "StockOptionLevel", "JobRole", "TrainingTimesLastYear", "JobInvolvement"], 
                        "dummies": [], # no metemos ninguna
                        'ordinal' : { }, #no metemos ninguna
                        "label": [] , # no metemos ninguna columna porque no queremos en ningún caso que se asignen las categorías de forma aleatoria
                        "frequency": [], # no metemos ninguna columna porque no coincide el orden del value counts con las categorias y la variable respuesta
                        "target": ["BusinessTravel", "Department", "MaritalStatus","NumCompaniesWorked", "EnvironmentSatisfaction", "JobSatisfaction", "WorkLifeBalance", "EducationField", "TotalWorkingYears"]  
                        }

# %%
cols_onehot = ["Gender", "DistanceFromHome", "Education", "JobLevel", "StockOptionLevel", "JobRole", "TrainingTimesLastYear", "JobInvolvement"]
one_hot_encoder = OneHotEncoder(categories='auto', 
                        drop=None, 
                        sparse_output=True, 
                        dtype='float', 
                        handle_unknown='error')

encoder_trans = one_hot_encoder.fit_transform(df_sinull_copy[cols_onehot])
encoder_array = encoder_trans.toarray()

# usamos el método get_feature_names_out() para extraer el nombre de las columnas
nombre_columnas = one_hot_encoder.get_feature_names_out()

encoder_df = pd.DataFrame(encoder_array, columns = nombre_columnas)
df_sinull_copy = pd.concat([df_sinull_copy, encoder_df], axis = 1)
df_sinull_copy.drop(columns=cols_onehot, inplace=True)

# %%
with open('../../transformers/preprocesamiento2/one_hot_encoder.pkl', 'wb') as o:
    pickle.dump(one_hot_encoder, o)

# %%
one_hot_encoder.categories_
# Out:
# [array(['Female', 'Male'], dtype=object),
#  array(['entre 1 y 4', 'entre 13 y 18', 'entre 19 y 23', 'entre 24 y 29',
#         'entre 5 y 8', 'entre 9 y 12'], dtype=object),
#  array(['Bachelor', 'Below College', 'College', 'Doctor', 'Master'],
#        dtype=object),
#  array(['Head', 'Intern', 'Junior', 'Manager', 'Senior'], dtype=object),
#  array(['Bad', 'Best', 'Better', 'Good'], dtype=object),
#  array(['Healthcare Representative', 'Human Resources',
#         'Laboratory Technician', 'Manager', 'Manufacturing Director',
#         'Research Director', 'Research Scientist', 'Sales Executive',
#         'Sales Representative'], dtype=object),
#  array([0., 1., 2., 3., 4., 5., 6.]),
#  array(['High', 'Low', 'Medium', 'Very High'], dtype=object)]

# %%
df_sinull_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 57 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1573 non-null   float64
#  1   Attrition                          1573 non-null   float64
#  2   BusinessTravel                     1573 non-null   object
#  3   Department                         1573 non-null   object
#  4   EducationField                     1573 non-null   object
#  5   MaritalStatus                      1573 non-null   object
#  6   MonthlyIncome                      1573 non-null   float64
#  7   NumCompaniesWorked                 1573 non-null   category
#  8   PercentSalaryHike                  1573 non-null   float64
#  9   TotalWorkingYears                  1573 non-null   category
#  10  YearsAtCompany                     1573 non-null   float64
#  11  YearsSinceLastPromotion            1573 non-null   float64
#  12  EnvironmentSatisfaction            1573 non-null   object
#  13  JobSatisfaction                    1573 non-null   object
#  14  WorkLifeBalance                    1573 non-null   object
#  15  Gender_Female                      1573 non-null   float64
#  16  Gender_Male                        1573 non-null   float64
#  17  DistanceFromHome_entre 1 y 4       1573 non-null   float64
#  18  DistanceFromHome_entre 13 y 18     1573 non-null   float64
#  19  DistanceFromHome_entre 19 y 23     1573 non-null   float64
#  20  DistanceFromHome_entre 24 y 29     1573 non-null   float64
#  21  DistanceFromHome_entre 5 y 8       1573 non-null   float64
#  22  DistanceFromHome_entre 9 y 12      1573 non-null   float64
#  23  Education_Bachelor                 1573 non-null   float64
#  24  Education_Below College            1573 non-null   float64
#  25  Education_College                  1573 non-null   float64
#  26  Education_Doctor                   1573 non-null   float64
#  27  Education_Master                   1573 non-null   float64
#  28  JobLevel_Head                      1573 non-null   float64
#  29  JobLevel_Intern                    1573 non-null   float64
#  30  JobLevel_Junior                    1573 non-null   float64
#  31  JobLevel_Manager                   1573 non-null   float64
#  32  JobLevel_Senior                    1573 non-null   float64
#  33  StockOptionLevel_Bad               1573 non-null   float64
#  34  StockOptionLevel_Best              1573 non-null   float64
#  35  StockOptionLevel_Better            1573 non-null   float64
#  36  StockOptionLevel_Good              1573 non-null   float64
#  37  JobRole_Healthcare Representative  1573 non-null   float64
#  38  JobRole_Human Resources            1573 non-null   float64
#  39  JobRole_Laboratory Technician      1573 non-null   float64
#  40  JobRole_Manager                    1573 non-null   float64
#  41  JobRole_Manufacturing Director     1573 non-null   float64
#  42  JobRole_Research Director          1573 non-null   float64
#  43  JobRole_Research Scientist         1573 non-null   float64
#  44  JobRole_Sales Executive            1573 non-null   float64
#  45  JobRole_Sales Representative       1573 non-null   float64
#  46  TrainingTimesLastYear_0.0          1573 non-null   float64
#  47  TrainingTimesLastYear_1.0          1573 non-null   float64
#  48  TrainingTimesLastYear_2.0          1573 non-null   float64
#  49  TrainingTimesLastYear_3.0          1573 non-null   float64
#  50  TrainingTimesLastYear_4.0          1573 non-null   float64
#  51  TrainingTimesLastYear_5.0          1573 non-null   float64
#  52  TrainingTimesLastYear_6.0          1573 non-null   float64
#  53  JobInvolvement_High                1573 non-null   float64
#  54  JobInvolvement_Low                 1573 non-null   float64
#  55  JobInvolvement_Medium              1573 non-null   float64
#  56  JobInvolvement_Very High           1573 non-null   float64
# dtypes: category(2), float64(48), object(7)
# memory usage: 680.8+ KB

# %%
target_encoder= TargetEncoder(cols=["BusinessTravel", "Department", "MaritalStatus","NumCompaniesWorked", "EnvironmentSatisfaction", "JobSatisfaction", "WorkLifeBalance", "EducationField", "TotalWorkingYears"])
encoded= target_encoder.fit_transform(df_sinull_copy , df_sinull_copy[["Attrition"]])

# %%
with open('../../transformers/preprocesamiento2/target_encoder.pkl', 'wb') as t:
    pickle.dump(target_encoder, t)

# %%
encoded.head(2)
# Out:
#     Age  Attrition  BusinessTravel  Department  EducationField  MaritalStatus  \
# 0 51.00       0.00            0.15        0.15            0.16           0.12
# 1 31.00       1.00            0.26        0.16            0.16           0.26
#
#    MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0       1,482.11                0.19              11.00               0.49
# 1         473.36                0.12              23.00               0.18
#
#    YearsAtCompany  YearsSinceLastPromotion  EnvironmentSatisfaction  \
# 0            1.00                     0.00                     0.14
# 1            5.00                     1.00                     0.14
#
#    JobSatisfaction  WorkLifeBalance  Gender_Female  Gender_Male  \
# 0             0.11             0.17           1.00         0.00
# 1             0.16             0.18           1.00         0.00
#
#    DistanceFromHome_entre 1 y 4  DistanceFromHome_entre 13 y 18  \
# 0                          0.00                            0.00
# 1                          0.00                            0.00
#
#    DistanceFromHome_entre 19 y 23  DistanceFromHome_entre 24 y 29  \
# 0                            0.00                            0.00
# 1                            0.00                            0.00
#
#    DistanceFromHome_entre 5 y 8  DistanceFromHome_entre 9 y 12  \
# 0                          1.00                           0.00
# 1                          0.00                           1.00
#
#    Education_Bachelor  Education_Below College  Education_College  \
# 0                0.00                     0.00               1.00
# 1                0.00                     1.00               0.00
#
#    Education_Doctor  Education_Master  JobLevel_Head  JobLevel_Intern  \
# 0              0.00              0.00           0.00             1.00
# 1              0.00              0.00           0.00             1.00
#
#    JobLevel_Junior  JobLevel_Manager  JobLevel_Senior  StockOptionLevel_Bad  \
# 0             0.00              0.00             0.00                  1.00
# 1             0.00              0.00             0.00                  0.00
#
#    StockOptionLevel_Best  StockOptionLevel_Better  StockOptionLevel_Good  \
# 0                   0.00                     0.00                   0.00
# 1                   0.00                     0.00                   1.00
#
#    JobRole_Healthcare Representative  JobRole_Human Resources  \
# 0                               1.00                     0.00
# 1                               0.00                     0.00
#
#    JobRole_Laboratory Technician  JobRole_Manager  \
# 0                           0.00             0.00
# 1                           0.00             0.00
#
#    JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                            0.00                       0.00
# 1                            0.00                       0.00
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                        0.00                     0.00
# 1                        1.00                     0.00
#
#    JobRole_Sales Representative  TrainingTimesLastYear_0.0  \
# 0                          0.00                       0.00
# 1                          0.00                       0.00
#
#    TrainingTimesLastYear_1.0  TrainingTimesLastYear_2.0  \
# 0                       0.00                       0.00
# 1                       0.00                       0.00
#
#    TrainingTimesLastYear_3.0  TrainingTimesLastYear_4.0  \
# 0                       0.00                       0.00
# 1                       1.00                       0.00
#
#    TrainingTimesLastYear_5.0  TrainingTimesLastYear_6.0  JobInvolvement_High  \
# 0                       0.00                       1.00                 1.00
# 1                       0.00                       0.00                 0.00
#
#    JobInvolvement_Low  JobInvolvement_Medium  JobInvolvement_Very High
# 0                0.00                   0.00                      0.00
# 1                0.00                   1.00                      0.00

# %%
encoded.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'EducationField',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance', 'Gender_Female', 'Gender_Male',
#        'DistanceFromHome_entre 1 y 4', 'DistanceFromHome_entre 13 y 18',
#        'DistanceFromHome_entre 19 y 23', 'DistanceFromHome_entre 24 y 29',
#        'DistanceFromHome_entre 5 y 8', 'DistanceFromHome_entre 9 y 12',
#        'Education_Bachelor', 'Education_Below College', 'Education_College',
#        'Education_Doctor', 'Education_Master', 'JobLevel_Head',
#        'JobLevel_Intern', 'JobLevel_Junior', 'JobLevel_Manager',
#        'JobLevel_Senior', 'StockOptionLevel_Bad', 'StockOptionLevel_Best',
#        'StockOptionLevel_Better', 'StockOptionLevel_Good',
#        'JobRole_Healthcare Representative', 'JobRole_Human Resources',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
#        'JobRole_Manufacturing Director', 'JobRole_Research Director',
#        'JobRole_Research Scientist', 'JobRole_Sales Executive',
#        'JobRole_Sales Representative', 'TrainingTimesLastYear_0.0',
#        'TrainingTimesLastYear_1.0', 'TrainingTimesLastYear_2.0',
#        'TrainingTimesLastYear_3.0', 'TrainingTimesLastYear_4.0',
#        'TrainingTimesLastYear_5.0', 'TrainingTimesLastYear_6.0',
#        'JobInvolvement_High', 'JobInvolvement_Low', 'JobInvolvement_Medium',
#        'JobInvolvement_Very High'],
#       dtype='object')

# %%
encoded.head()
# Out:
#     Age  Attrition  BusinessTravel  Department  EducationField  MaritalStatus  \
# 0 51.00       0.00            0.15        0.15            0.16           0.12
# 1 31.00       1.00            0.26        0.16            0.16           0.26
# 2 32.00       0.00            0.26        0.16            0.11           0.12
# 3 38.00       0.00            0.08        0.16            0.16           0.12
# 4 32.00       0.00            0.15        0.16            0.17           0.26
#
#    MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0       1,482.11                0.19              11.00               0.49
# 1         473.36                0.12              23.00               0.18
# 2       2,184.06                0.19              15.00               0.18
# 3         940.27                0.10              11.00               0.09
# 4         264.65                0.13              12.00               0.11
#
#    YearsAtCompany  YearsSinceLastPromotion  EnvironmentSatisfaction  \
# 0            1.00                     0.00                     0.14
# 1            5.00                     1.00                     0.14
# 2            5.00                     0.00                     0.15
# 3            8.00                     7.00                     0.13
# 4            6.00                     0.00                     0.13
#
#    JobSatisfaction  WorkLifeBalance  Gender_Female  Gender_Male  \
# 0             0.11             0.17           1.00         0.00
# 1             0.16             0.18           1.00         0.00
# 2             0.16             0.32           0.00         1.00
# 3             0.11             0.14           0.00         1.00
# 4             0.23             0.14           0.00         1.00
#
#    DistanceFromHome_entre 1 y 4  DistanceFromHome_entre 13 y 18  \
# 0                          0.00                            0.00
# 1                          0.00                            0.00
# 2                          0.00                            1.00
# 3                          1.00                            0.00
# 4                          0.00                            0.00
#
#    DistanceFromHome_entre 19 y 23  DistanceFromHome_entre 24 y 29  \
# 0                            0.00                            0.00
# 1                            0.00                            0.00
# 2                            0.00                            0.00
# 3                            0.00                            0.00
# 4                            0.00                            0.00
#
#    DistanceFromHome_entre 5 y 8  DistanceFromHome_entre 9 y 12  \
# 0                          1.00                           0.00
# 1                          0.00                           1.00
# 2                          0.00                           0.00
# 3                          0.00                           0.00
# 4                          0.00                           1.00
#
#    Education_Bachelor  Education_Below College  Education_College  \
# 0                0.00                     0.00               1.00
# 1                0.00                     1.00               0.00
# 2                0.00                     0.00               0.00
# 3                0.00                     0.00               0.00
# 4                0.00                     1.00               0.00
#
#    Education_Doctor  Education_Master  JobLevel_Head  JobLevel_Intern  \
# 0              0.00              0.00           0.00             1.00
# 1              0.00              0.00           0.00             1.00
# 2              0.00              1.00           0.00             0.00
# 3              1.00              0.00           0.00             0.00
# 4              0.00              0.00           0.00             1.00
#
#    JobLevel_Junior  JobLevel_Manager  JobLevel_Senior  StockOptionLevel_Bad  \
# 0             0.00              0.00             0.00                  1.00
# 1             0.00              0.00             0.00                  0.00
# 2             0.00              1.00             0.00                  0.00
# 3             0.00              0.00             1.00                  0.00
# 4             0.00              0.00             0.00                  0.00
#
#    StockOptionLevel_Best  StockOptionLevel_Better  StockOptionLevel_Good  \
# 0                   0.00                     0.00                   0.00
# 1                   0.00                     0.00                   1.00
# 2                   1.00                     0.00                   0.00
# 3                   1.00                     0.00                   0.00
# 4                   0.00                     1.00                   0.00
#
#    JobRole_Healthcare Representative  JobRole_Human Resources  \
# 0                               1.00                     0.00
# 1                               0.00                     0.00
# 2                               0.00                     0.00
# 3                               0.00                     1.00
# 4                               0.00                     0.00
#
#    JobRole_Laboratory Technician  JobRole_Manager  \
# 0                           0.00             0.00
# 1                           0.00             0.00
# 2                           0.00             0.00
# 3                           0.00             0.00
# 4                           0.00             0.00
#
#    JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                            0.00                       0.00
# 1                            0.00                       0.00
# 2                            0.00                       0.00
# 3                            0.00                       0.00
# 4                            0.00                       0.00
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                        0.00                     0.00
# 1                        1.00                     0.00
# 2                        0.00                     1.00
# 3                        0.00                     0.00
# 4                        0.00                     1.00
#
#    JobRole_Sales Representative  TrainingTimesLastYear_0.0  \
# 0                          0.00                       0.00
# 1                          0.00                       0.00
# 2                          0.00                       0.00
# 3                          0.00                       0.00
# 4                          0.00                       0.00
#
#    TrainingTimesLastYear_1.0  TrainingTimesLastYear_2.0  \
# 0                       0.00                       0.00
# 1                       0.00                       0.00
# 2                       0.00                       1.00
# 3                       0.00                       0.00
# 4                       0.00                       1.00
#
#    TrainingTimesLastYear_3.0  TrainingTimesLastYear_4.0  \
# 0                       0.00                       0.00
# 1                       1.00                       0.00
# 2                       0.00                       0.00
# 3                       0.00                       0.00
# 4                       0.00                       0.00
#
#    TrainingTimesLastYear_5.0  TrainingTimesLastYear_6.0  JobInvolvement_High  \
# 0                       0.00                       1.00                 1.00
# 1                       0.00                       0.00                 0.00
# 2                       0.00                       0.00                 1.00
# 3                       1.00                       0.00                 0.00
# 4                       0.00                       0.00                 1.00
#
#    JobInvolvement_Low  JobInvolvement_Medium  JobInvolvement_Very High
# 0                0.00                   0.00                      0.00
# 1                0.00                   1.00                      0.00
# 2                0.00                   0.00                      0.00
# 3                0.00                   1.00                      0.00
# 4                0.00                   0.00                      0.00

# %% [markdown]
# ### **DESBALANCEO**

# %%
round(encoded["Attrition"].value_counts(normalize=True)*100,2)
# Out:
# Attrition
# 0.00   83.98
# 1.00   16.02
# Name: proportion, dtype: float64

# %%
desbalanceo=b.Desbalanceo(encoded,"Attrition")
desbalanceo.visualizar_clase(color="blue", edgecolor="black")

# %% [markdown]
# #### **USO UN SMOTENC PARA QUE NO TOUE LAS CATEGORICAS**

# %%
columnas_son_cat_encoded=['Gender_Female', 'Gender_Male',
       'DistanceFromHome_entre 1 y 4', 'DistanceFromHome_entre 13 y 18',
       'DistanceFromHome_entre 19 y 23', 'DistanceFromHome_entre 24 y 29',
       'DistanceFromHome_entre 5 y 8', 'DistanceFromHome_entre 9 y 12',
       'Education_Bachelor', 'Education_Below College', 'Education_College',
       'Education_Doctor', 'Education_Master', 'JobLevel_Head',
       'JobLevel_Intern', 'JobLevel_Junior', 'JobLevel_Manager',
       'JobLevel_Senior', 'StockOptionLevel_Bad', 'StockOptionLevel_Best',
       'StockOptionLevel_Better', 'StockOptionLevel_Good',
       'JobRole_Healthcare Representative', 'JobRole_Human Resources',
       'JobRole_Laboratory Technician', 'JobRole_Manager',
       'JobRole_Manufacturing Director', 'JobRole_Research Director',
       'JobRole_Research Scientist', 'JobRole_Sales Executive',
       'JobRole_Sales Representative', 'TrainingTimesLastYear_0.0',
       'TrainingTimesLastYear_1.0', 'TrainingTimesLastYear_2.0',
       'TrainingTimesLastYear_3.0', 'TrainingTimesLastYear_4.0',
       'TrainingTimesLastYear_5.0', 'TrainingTimesLastYear_6.0',
       'JobInvolvement_High', 'JobInvolvement_Low', 'JobInvolvement_Medium',
       'JobInvolvement_Very High'
       ,"BusinessTravel", "Department", "MaritalStatus","NumCompaniesWorked", "EnvironmentSatisfaction", "JobSatisfaction", "WorkLifeBalance", "EducationField", "TotalWorkingYears"]

# %%
encoded.shape
# Out:
# (1573, 57)

# %%
encoded.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'EducationField',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance', 'Gender_Female', 'Gender_Male',
#        'DistanceFromHome_entre 1 y 4', 'DistanceFromHome_entre 13 y 18',
#        'DistanceFromHome_entre 19 y 23', 'DistanceFromHome_entre 24 y 29',
#        'DistanceFromHome_entre 5 y 8', 'DistanceFromHome_entre 9 y 12',
#        'Education_Bachelor', 'Education_Below College', 'Education_College',
#        'Education_Doctor', 'Education_Master', 'JobLevel_Head',
#        'JobLevel_Intern', 'JobLevel_Junior', 'JobLevel_Manager',
#        'JobLevel_Senior', 'StockOptionLevel_Bad', 'StockOptionLevel_Best',
#        'StockOptionLevel_Better', 'StockOptionLevel_Good',
#        'JobRole_Healthcare Representative', 'JobRole_Human Resources',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
#        'JobRole_Manufacturing Director', 'JobRole_Research Director',
#        'JobRole_Research Scientist', 'JobRole_Sales Executive',
#        'JobRole_Sales Representative', 'TrainingTimesLastYear_0.0',
#        'TrainingTimesLastYear_1.0', 'TrainingTimesLastYear_2.0',
#        'TrainingTimesLastYear_3.0', 'TrainingTimesLastYear_4.0',
#        'TrainingTimesLastYear_5.0', 'TrainingTimesLastYear_6.0',
#        'JobInvolvement_High', 'JobInvolvement_Low', 'JobInvolvement_Medium',
#        'JobInvolvement_Very High'],
#       dtype='object')

# %%
df_balanceado_smote=desbalanceo.balancear_clase_smotenc(columnas_son_cat_encoded)

# %%
df_balanceado_smote.head(3)
# Out:
#     Age  BusinessTravel  Department  EducationField  MaritalStatus  \
# 0 51.00            0.15        0.15            0.16           0.12
# 1 31.00            0.26        0.16            0.16           0.26
# 2 32.00            0.26        0.16            0.11           0.12
#
#    MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0       1,482.11                0.19              11.00               0.49
# 1         473.36                0.12              23.00               0.18
# 2       2,184.06                0.19              15.00               0.18
#
#    YearsAtCompany  YearsSinceLastPromotion  EnvironmentSatisfaction  \
# 0            1.00                     0.00                     0.14
# 1            5.00                     1.00                     0.14
# 2            5.00                     0.00                     0.15
#
#    JobSatisfaction  WorkLifeBalance  Gender_Female  Gender_Male  \
# 0             0.11             0.17           1.00         0.00
# 1             0.16             0.18           1.00         0.00
# 2             0.16             0.32           0.00         1.00
#
#    DistanceFromHome_entre 1 y 4  DistanceFromHome_entre 13 y 18  \
# 0                          0.00                            0.00
# 1                          0.00                            0.00
# 2                          0.00                            1.00
#
#    DistanceFromHome_entre 19 y 23  DistanceFromHome_entre 24 y 29  \
# 0                            0.00                            0.00
# 1                            0.00                            0.00
# 2                            0.00                            0.00
#
#    DistanceFromHome_entre 5 y 8  DistanceFromHome_entre 9 y 12  \
# 0                          1.00                           0.00
# 1                          0.00                           1.00
# 2                          0.00                           0.00
#
#    Education_Bachelor  Education_Below College  Education_College  \
# 0                0.00                     0.00               1.00
# 1                0.00                     1.00               0.00
# 2                0.00                     0.00               0.00
#
#    Education_Doctor  Education_Master  JobLevel_Head  JobLevel_Intern  \
# 0              0.00              0.00           0.00             1.00
# 1              0.00              0.00           0.00             1.00
# 2              0.00              1.00           0.00             0.00
#
#    JobLevel_Junior  JobLevel_Manager  JobLevel_Senior  StockOptionLevel_Bad  \
# 0             0.00              0.00             0.00                  1.00
# 1             0.00              0.00             0.00                  0.00
# 2             0.00              1.00             0.00                  0.00
#
#    StockOptionLevel_Best  StockOptionLevel_Better  StockOptionLevel_Good  \
# 0                   0.00                     0.00                   0.00
# 1                   0.00                     0.00                   1.00
# 2                   1.00                     0.00                   0.00
#
#    JobRole_Healthcare Representative  JobRole_Human Resources  \
# 0                               1.00                     0.00
# 1                               0.00                     0.00
# 2                               0.00                     0.00
#
#    JobRole_Laboratory Technician  JobRole_Manager  \
# 0                           0.00             0.00
# 1                           0.00             0.00
# 2                           0.00             0.00
#
#    JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                            0.00                       0.00
# 1                            0.00                       0.00
# 2                            0.00                       0.00
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                        0.00                     0.00
# 1                        1.00                     0.00
# 2                        0.00                     1.00
#
#    JobRole_Sales Representative  TrainingTimesLastYear_0.0  \
# 0                          0.00                       0.00
# 1                          0.00                       0.00
# 2                          0.00                       0.00
#
#    TrainingTimesLastYear_1.0  TrainingTimesLastYear_2.0  \
# 0                       0.00                       0.00
# 1                       0.00                       0.00
# 2                       0.00                       1.00
#
#    TrainingTimesLastYear_3.0  TrainingTimesLastYear_4.0  \
# 0                       0.00                       0.00
# 1                       1.00                       0.00
# 2                       0.00                       0.00
#
#    TrainingTimesLastYear_5.0  TrainingTimesLastYear_6.0  JobInvolvement_High  \
# 0                       0.00                       1.00                 1.00
# 1                       0.00                       0.00                 0.00
# 2                       0.00                       0.00                 1.00
#
#    JobInvolvement_Low  JobInvolvement_Medium  JobInvolvement_Very High  \
# 0                0.00                   0.00                      0.00
# 1                0.00                   1.00                      0.00
# 2                0.00                   0.00                      0.00
#
#    Attrition
# 0       0.00
# 1       1.00
# 2       0.00

# %%
round(df_balanceado_smote["Attrition"].value_counts(normalize=True)*100,2)
# Out:
# Attrition
# 0.00   50.00
# 1.00   50.00
# Name: proportion, dtype: float64

# %% [markdown]
# revisar que valores unicos de Attrition se hayan mantenido

# %%
df_balanceado_smote.shape
# Out:
# (2642, 57)

# %% [markdown]
# El uso del Tomek para refinar un posible sobreajuste lo dejo para más adelante porque primero quiero ver como sale solo con el **smotenc**

# %% [markdown]
# <!-- #### **AHORA USO UN TOMEK**
# -  Elimina pares de muestras cercanas entre la clase mayoritaria y la clase minoritaria donde el vecino más cercano de un punto de la clase minoritaria pertenece a la clase mayoritaria. -->

# %%
# desbalanceo.balancear_clases_tomek()

# %%
encoded.to_pickle("../../datos/datos2/datos_sinnull_encoded_balanced.pkl")
