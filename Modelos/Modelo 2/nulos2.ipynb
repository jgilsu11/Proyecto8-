# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Otros objetivos
# -----------------------------------------------------------------------
import math

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

import os
import sys 
sys.path.append(os.path.abspath("../../src"))   
import Soporte_preprocesamiento as f
import warnings
warnings.filterwarnings("ignore")

import json
from datetime import datetime

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestRegressor

# Para tratar el problema de desbalance
# -----------------------------------------------------------------------
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek


pd.set_option("display.max_columns", None)

# %% [markdown]
# La variable dependiente es **"Atrittion"**

# %%
data_general=pd.read_csv("../../datos/datos0/general_data.csv")

# %%
data_general.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# 1         Research Scientist        Single          41890                 0.0
# 2            Sales Executive       Married         193280                 1.0
# 3            Human Resources       Married          83210                 3.0
# 4            Sales Executive        Single          23420                 4.0
#
#   Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 0      Y                 11              8                 0
# 1      Y                 23              8                 1
# 2      Y                 15              8                 3
# 3      Y                 11              8                 3
# 4      Y                 12              8                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0                      6               1
# 1                6.0                      3               5
# 2                5.0                      2               5
# 3               13.0                      5               8
# 4                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4

# %%
data_general.shape
# Out:
# (4410, 24)

# %%
empleados=pd.read_csv("../../datos/datos0/employee_survey_data.csv")

# %%
empleados.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
empleados.shape
# Out:
# (4410, 4)

# %%
empleados.drop(columns="EmployeeID", inplace=True)

# %%
managers=pd.read_csv("../../datos/datos0/manager_survey_data.csv")

# %%
managers.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
managers.drop(columns="EmployeeID", inplace=True)

# %%
managers.shape
# Out:
# (4410, 2)

# %% [markdown]
# # PRIMERO VAMOS A JUNTAR LAS DISTINTAS TABLAS

# %%
df_crudo=pd.DataFrame()
df_crudo=pd.concat([df_crudo, data_general, empleados, managers], axis=1)

# %%
df_crudo.head(2)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# 1         Research Scientist        Single          41890                 0.0
#
#   Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 0      Y                 11              8                 0
# 1      Y                 23              8                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0                      6               1
# 1                6.0                      3               5
#
#    YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# 0                        0                     0                      3.0
# 1                        1                     4                      3.0
#
#    JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0              4.0              2.0               3                  3
# 1              2.0              4.0               2                  4

# %% [markdown]
# ### Dropeamos EmployeeID

# %%
df_crudo.drop(columns="EmployeeID", inplace=True)

# %% [markdown]
# **CONVERTIMOS A NUMÉRICA LA VARIABLE DEPENDIENTE**

# %%
dicc_dependiente={"No":0,
                  "Yes":1}
df_crudo["Attrition"]=df_crudo["Attrition"].map(dicc_dependiente)

# %%
f.exploracion_dataframe(df_crudo, "Attrition")
# Out:
# El número de datos es 4410 y el de columnas es 28
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 2837
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                           %_nulos
# NumCompaniesWorked       0.430839
# TotalWorkingYears        0.204082
# EnvironmentSatisfaction  0.566893
# JobSatisfaction          0.453515
# WorkLifeBalance          0.861678
#  .....................
#
# Los tipos de las columnas son:
#                         tipo_dato
# Age                         int64
# Attrition                   int64
# BusinessTravel             object
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EmployeeCount               int64
# Gender                     object
# JobLevel                    int64
# JobRole                    object
# MaritalStatus              object
# MonthlyIncome               int64
# NumCompaniesWorked        float64
# Over18                     object
# PercentSalaryHike           int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears         float64
# TrainingTimesLastYear       int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# EnvironmentSatisfaction   float64
# JobSatisfaction           float64
# WorkLifeBalance           float64
# JobInvolvement              int64
# PerformanceRating           int64
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna BUSINESSTRAVEL tiene los siguientes valores únicos:
# Mostrando 3 categorías con más valores del total de 3 categorías (3/3)
#                    count
# BusinessTravel
# Travel_Rarely       3129
# Travel_Frequently    831
# Non-Travel           450
# La columna DEPARTMENT tiene los siguientes valores únicos:
# Mostrando 3 categorías con más valores del total de 3 categorías (3/3)
#                         count
# Department
# Research & Development   2883
# Sales                    1338
# Human Resources           189
# La columna EDUCATIONFIELD tiene los siguientes valores únicos:
# Mostrando 5 categorías con más valores del total de 6 categorías (5/6)
#                   count
# EducationField
# Life Sciences      1818
# Medical            1392
# Marketing           477
# Technical Degree    396
# Other               246
# La columna GENDER tiene los siguientes valores únicos:
# Mostrando 2 categorías con más valores del total de 2 categorías (2/2)
#         count
# Gender
# Male     2646
# Female   1764
# La columna JOBROLE tiene los siguientes valores únicos:
# Mostrando 5 categorías con más valores del total de 9 categorías (5/9)
#                            count
# JobRole
# Sales Executive              978
# Research Scientist           876
# Laboratory Technician        777
# Manufacturing Director       435
# Healthcare Representative    393
# La columna MARITALSTATUS tiene los siguientes valores únicos:
# Mostrando 3 categorías con más valores del total de 3 categorías (3/3)
#                count
# MaritalStatus
# Married         2019
# Single          1410
# Divorced         981
# La columna OVER18 tiene los siguientes valores únicos:
# Mostrando 1 categorías con más valores del total de 1 categorías (1/1)
#         count
# Over18
# Y        4410
# ----------
#
# Las principales estadísticas de las variables númericas son:
#                           count          mean           std      min      25%  \
# Age                      4410.0     36.923810      9.133301     18.0     30.0
# Attrition                4410.0      0.161224      0.367780      0.0      0.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0      2.0
# Education                4410.0      2.912925      1.023933      1.0      2.0
# EmployeeCount            4410.0      1.000000      0.000000      1.0      1.0
# JobLevel                 4410.0      2.063946      1.106689      1.0      1.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0  29110.0
# NumCompaniesWorked       4391.0      2.694830      2.498887      0.0      1.0
# PercentSalaryHike        4410.0     15.209524      3.659108     11.0     12.0
# StandardHours            4410.0      8.000000      0.000000      8.0      8.0
# StockOptionLevel         4410.0      0.793878      0.851883      0.0      0.0
# TotalWorkingYears        4401.0     11.279936      7.782222      0.0      6.0
# TrainingTimesLastYear    4410.0      2.799320      1.288978      0.0      2.0
# YearsAtCompany           4410.0      7.008163      6.125135      0.0      3.0
# YearsSinceLastPromotion  4410.0      2.187755      3.221699      0.0      0.0
# YearsWithCurrManager     4410.0      4.123129      3.567327      0.0      2.0
# EnvironmentSatisfaction  4385.0      2.723603      1.092756      1.0      2.0
# JobSatisfaction          4390.0      2.728246      1.101253      1.0      2.0
# WorkLifeBalance          4372.0      2.761436      0.706245      1.0      2.0
# JobInvolvement           4410.0      2.729932      0.711400      1.0      2.0
# PerformanceRating        4410.0      3.153741      0.360742      3.0      3.0
#
#                              50%      75%       max
# Age                         36.0     43.0      60.0
# Attrition                    0.0      0.0       1.0
# DistanceFromHome             7.0     14.0      29.0
# Education                    3.0      4.0       5.0
# EmployeeCount                1.0      1.0       1.0
# JobLevel                     2.0      3.0       5.0
# MonthlyIncome            49190.0  83800.0  199990.0
# NumCompaniesWorked           2.0      4.0       9.0
# PercentSalaryHike           14.0     18.0      25.0
# StandardHours                8.0      8.0       8.0
# StockOptionLevel             1.0      1.0       3.0
# TotalWorkingYears           10.0     15.0      40.0
# TrainingTimesLastYear        3.0      3.0       6.0
# YearsAtCompany               5.0      9.0      40.0
# YearsSinceLastPromotion      1.0      3.0      15.0
# YearsWithCurrManager         3.0      7.0      17.0
# EnvironmentSatisfaction      3.0      4.0       4.0
# JobSatisfaction              3.0      4.0       4.0
# WorkLifeBalance              3.0      3.0       4.0
# JobInvolvement               3.0      3.0       4.0
# PerformanceRating            3.0      3.0       4.0
# ----------
#
# Las principales estadísticas de las variables categóricas son:
#                count unique                     top  freq
# BusinessTravel  4410      3           Travel_Rarely  3129
# Department      4410      3  Research & Development  2883
# EducationField  4410      6           Life Sciences  1818
# Gender          4410      2                    Male  2646
# JobRole         4410      9         Sales Executive   978
# MaritalStatus   4410      3                 Married  2019
# Over18          4410      1                       Y  4410
# ----------
#
# Las características principales del dataframe son:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   int64
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   Gender                   4410 non-null   object
#  9   JobLevel                 4410 non-null   int64
#  10  JobRole                  4410 non-null   object
#  11  MaritalStatus            4410 non-null   object
#  12  MonthlyIncome            4410 non-null   int64
#  13  NumCompaniesWorked       4391 non-null   float64
#  14  Over18                   4410 non-null   object
#  15  PercentSalaryHike        4410 non-null   int64
#  16  StandardHours            4410 non-null   int64
#  17  StockOptionLevel         4410 non-null   int64
#  18  TotalWorkingYears        4401 non-null   float64
#  19  TrainingTimesLastYear    4410 non-null   int64
#  20  YearsAtCompany           4410 non-null   int64
#  21  YearsSinceLastPromotion  4410 non-null   int64
#  22  YearsWithCurrManager     4410 non-null   int64
#  23  EnvironmentSatisfaction  4385 non-null   float64
#  24  JobSatisfaction          4390 non-null   float64
#  25  WorkLifeBalance          4372 non-null   float64
#  26  JobInvolvement           4410 non-null   int64
#  27  PerformanceRating        4410 non-null   int64
# dtypes: float64(5), int64(16), object(7)
# memory usage: 964.8+ KB
# None

# %% [markdown]
# #### **GESTIONAMOS LOS DUPLICADOS QUE SE GENERAN AL ELIMINAR EMPLOYEEID**

# %%
df_crudo[df_crudo.duplicated()].head(3)
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 1471   31          1  Travel_Frequently  Research & Development
# 1472   32          0  Travel_Frequently  Research & Development
# 1473   38          0         Non-Travel  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# 1471                10          1  Life Sciences              1  Female
# 1472                17          4          Other              1    Male
# 1473                 2          5  Life Sciences              1    Male
#
#       JobLevel             JobRole MaritalStatus  MonthlyIncome  \
# 1471         1  Research Scientist        Single          41890
# 1472         4     Sales Executive       Married         193280
# 1473         3     Human Resources       Married          83210
#
#       NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# 1471                 0.0      Y                 23              8
# 1472                 1.0      Y                 15              8
# 1473                 3.0      Y                 11              8
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1471                 1                6.0                      3
# 1472                 3                5.0                      2
# 1473                 3               13.0                      5
#
#       YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# 1471               5                        1                     4
# 1472               5                        0                     3
# 1473               8                        7                     5
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 1471                      3.0              2.0              4.0
# 1472                      2.0              2.0              1.0
# 1473                      4.0              4.0              3.0
#
#       JobInvolvement  PerformanceRating
# 1471               2                  4
# 1472               3                  3
# 1473               2                  3

# %%
df_crudo.drop_duplicates(inplace=True)
df_crudo.reset_index(drop=True,inplace=True)

# %%
df_crudo.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### **COLUMNAS IRRELEVANTES**

# %%
df_crudo["StandardHours"].value_counts()
# Out:
# StandardHours
# 8    1573
# Name: count, dtype: int64

# %%
df_crudo["PerformanceRating"].value_counts()
# Out:
# PerformanceRating
# 3    1333
# 4     240
# Name: count, dtype: int64

# %%
columnas_eliminar=["StandardHours", "EmployeeCount","Over18", "PerformanceRating"]

# %%
df_crudo.drop(columns=columnas_eliminar, inplace=True)

# %% [markdown]
# ### **NULOS**

# %%
(df_crudo.isna().sum() != 0).sum()    #tenemos 5 columnas con nulos:NumCompaniesWorked, TotalWorkingYears ,EnvironmentSatisfaction ,JobSatisfaction	,WorkLifeBalance
# Out:
# 5

# %%
df_crudo.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    23
# JobSatisfaction            18
# WorkLifeBalance            35
# JobInvolvement              0
# dtype: int64

# %% [markdown]
# ***USO KNN PARA IMPUTAR NULOS***

# %%
df_numericas=df_crudo.select_dtypes(include=np.number)
imputer_knn= KNNImputer(n_neighbors=5)                   #por defecto siempre lo calcula en base a la media y no se puede cambiar
knn_imputado= imputer_knn.fit_transform(df_numericas)    #como es solo para numericas se tiene que meter el df de numericas
df_knn=df_crudo.copy()
df_num_sin_nulos=pd.DataFrame(knn_imputado, columns= df_numericas.columns)  #para que tenga los mismo nombres de columnas
df_knn[df_numericas.columns]= df_num_sin_nulos           #Con esto metemos todo el dataframe de las numericas sin nulos donde corresponda rellenando esos nulos

# %%
(df_knn.isna().sum() != 0).sum()
# Out:
# 0

# %% [markdown]
# ### **FORMATEOS**

# %%
df_knn.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# dtype: int64

# %%
dicc_distancia={1:"entre 1 y 4",
                2:"entre 1 y 4",
                3:"entre 1 y 4",
                4:"entre 1 y 4",
                5:"entre 5 y 8",
                6:"entre 5 y 8",
                7:"entre 5 y 8",
                8:"entre 5 y 8",
                9:"entre 9 y 12",
                10:"entre 9 y 12",
                11:"entre 9 y 12",
                12:"entre 9 y 12",
                13:"entre 13 y 18",
                14:"entre 13 y 18",
                15:"entre 13 y 18",
                16:"entre 13 y 18",
                17:"entre 13 y 18",
                18:"entre 13 y 18",
                19:"entre 19 y 23",
                20:"entre 19 y 23",
                21:"entre 19 y 23",
                22:"entre 19 y 23",
                23:"entre 19 y 23",
                24:"entre 24 y 29",
                25:"entre 24 y 29",
                26:"entre 24 y 29",
                27:"entre 24 y 29",
                28:"entre 24 y 29",
                29:"entre 24 y 29"}

# %%
df_knn["DistanceFromHome"]=df_knn["DistanceFromHome"].map(dicc_distancia)

# %%
df_knn["DistanceFromHome"].value_counts()
# Out:
# DistanceFromHome
# entre 1 y 4      614
# entre 5 y 8      310
# entre 9 y 12     227
# entre 13 y 18    151
# entre 24 y 29    150
# entre 19 y 23    121
# Name: count, dtype: int64

# %% [markdown]
# **CONVERTIMOS A CATEGÓRICAS**

# %%
lista_cols_convertir=["Education","JobLevel","NumCompaniesWorked","StockOptionLevel","TrainingTimesLastYear","EnvironmentSatisfaction","JobSatisfaction","WorkLifeBalance","JobInvolvement", "DistanceFromHome"]
df_formateado=f.convertir_a_cat(lista_cols_convertir,df_knn)

# %%
df_formateado.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 0  51.0        0.0      Travel_Rarely                   Sales
# 1  31.0        1.0  Travel_Frequently  Research & Development
# 2  32.0        0.0  Travel_Frequently  Research & Development
# 3  38.0        0.0         Non-Travel  Research & Development
# 4  32.0        0.0      Travel_Rarely  Research & Development
#
#   DistanceFromHome Education EducationField  Gender JobLevel  \
# 0      entre 5 y 8       2.0  Life Sciences  Female      1.0
# 1     entre 9 y 12       1.0  Life Sciences  Female      1.0
# 2    entre 13 y 18       4.0          Other    Male      4.0
# 3      entre 1 y 4       5.0  Life Sciences    Male      3.0
# 4     entre 9 y 12       1.0        Medical    Male      1.0
#
#                      JobRole MaritalStatus  MonthlyIncome NumCompaniesWorked  \
# 0  Healthcare Representative       Married       131160.0                1.0
# 1         Research Scientist        Single        41890.0                0.0
# 2            Sales Executive       Married       193280.0                1.0
# 3            Human Resources       Married        83210.0                3.0
# 4            Sales Executive        Single        23420.0                4.0
#
#    PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 0               11.0              0.0                1.0
# 1               23.0              1.0                6.0
# 2               15.0              3.0                5.0
# 3               11.0              3.0               13.0
# 4               12.0              2.0                9.0
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                   6.0             1.0                      0.0
# 1                   3.0             5.0                      1.0
# 2                   2.0             5.0                      0.0
# 3                   5.0             8.0                      7.0
# 4                   2.0             6.0                      0.0
#
#    YearsWithCurrManager EnvironmentSatisfaction JobSatisfaction  \
# 0                   0.0                     3.0             4.0
# 1                   4.0                     3.0             2.0
# 2                   3.0                     2.0             2.0
# 3                   5.0                     4.0             4.0
# 4                   4.0                     4.0             1.0
#
#   WorkLifeBalance JobInvolvement
# 0             2.0            3.0
# 1             4.0            2.0
# 2             1.0            3.0
# 3             3.0            2.0
# 4             3.0            3.0

# %%
df_formateado.shape
# Out:
# (1573, 24)

# %%
df_formateado.describe().T
# Out:
#                           count          mean           std      min      25%  \
# Age                      1573.0     36.904005      9.105911     18.0     30.0
# Attrition                1573.0      0.160203      0.366911      0.0      0.0
# MonthlyIncome            1573.0  64979.459631  47121.739301  10090.0  28990.0
# PercentSalaryHike        1573.0     15.202161      3.646403     11.0     12.0
# TotalWorkingYears        1573.0     11.245264      7.729839      0.0      6.0
# YearsAtCompany           1573.0      6.970757      6.068348      0.0      3.0
# YearsSinceLastPromotion  1573.0      2.184361      3.203105      0.0      0.0
# YearsWithCurrManager     1573.0      4.102988      3.572701      0.0      2.0
#
#                              50%      75%       max
# Age                         36.0     43.0      60.0
# Attrition                    0.0      0.0       1.0
# MonthlyIncome            49000.0  83800.0  199990.0
# PercentSalaryHike           14.0     18.0      25.0
# TotalWorkingYears           10.0     15.0      40.0
# YearsAtCompany               5.0      9.0      40.0
# YearsSinceLastPromotion      1.0      3.0      15.0
# YearsWithCurrManager         3.0      7.0      17.0

# %% [markdown]
# **Pasamos el MONTHLYINCOME de Rupias a Euros con una tasa 0,0113**

# %%
df_formateado["MonthlyIncome"]=df_formateado["MonthlyIncome"].apply(lambda x: x * 0.0113)

# %%
df_formateado.describe().T
# Out:
#                           count        mean         std      min      25%  \
# Age                      1573.0   36.904005    9.105911   18.000   30.000
# Attrition                1573.0    0.160203    0.366911    0.000    0.000
# MonthlyIncome            1573.0  734.267894  532.475654  114.017  327.587
# PercentSalaryHike        1573.0   15.202161    3.646403   11.000   12.000
# TotalWorkingYears        1573.0   11.245264    7.729839    0.000    6.000
# YearsAtCompany           1573.0    6.970757    6.068348    0.000    3.000
# YearsSinceLastPromotion  1573.0    2.184361    3.203105    0.000    0.000
# YearsWithCurrManager     1573.0    4.102988    3.572701    0.000    2.000
#
#                            50%     75%       max
# Age                       36.0   43.00    60.000
# Attrition                  0.0    0.00     1.000
# MonthlyIncome            553.7  946.94  2259.887
# PercentSalaryHike         14.0   18.00    25.000
# TotalWorkingYears         10.0   15.00    40.000
# YearsAtCompany             5.0    9.00    40.000
# YearsSinceLastPromotion    1.0    3.00    15.000
# YearsWithCurrManager       3.0    7.00    17.000

# %% [markdown]
# **AHORA PASAMOS ALGUNAS CATEGORICAS CON NUMEROS A CATEGRICAS DE TEXTO**

# %%
dicc_edu={1 :'Below College',
2 :'College',
3 :'Bachelor',
4 :'Master',
5 :'Doctor'}

df_formateado["Education"]=df_formateado["Education"].map(dicc_edu)

# %%
def agrupar_rangos(valor):
    """
    Agrupa valores en rangos redondeando al entero más cercano.
    Por ejemplo:
    - Valores entre 1 y 1.5 se agrupan en 1.
    - Valores entre 1.6 y 2.5 se agrupan en 2.
    """
    if 1 <= valor < 1.5:
        return 'Low'
    elif 1.5 <= valor < 2.5:
        return 'Medium'
    elif 2.5 <= valor < 3.5:
        return 'High'
    elif 3.5 <= valor < 4.5:
        return 'Very High'
    else:
        return None  # Manejo de valores fuera del rango esperado
df_formateado['EnvironmentSatisfaction'] = df_formateado['EnvironmentSatisfaction'].apply(agrupar_rangos)

# %%
df_formateado['TotalWorkingYears'] = df_formateado['TotalWorkingYears'].apply(lambda x: round(x))

# %%
df_formateado["TotalWorkingYears"].value_counts()
# Out:
# TotalWorkingYears
# 10    218
# 6     132
# 8     111
# 9     105
# 5      97
# 7      90
# 1      84
# 4      67
# 12     51
# 3      45
# 15     42
# 16     41
# 11     38
# 21     37
# 13     37
# 14     35
# 17     33
# 20     32
# 2      31
# 18     28
# 22     24
# 19     23
# 23     22
# 24     18
# 26     16
# 25     15
# 28     15
# 0      13
# 29     10
# 32     10
# 31      9
# 27      8
# 33      7
# 30      7
# 36      6
# 34      6
# 37      4
# 35      3
# 40      2
# 38      1
# Name: count, dtype: int64

# %%
df_formateado['NumCompaniesWorked'] = df_formateado['NumCompaniesWorked'].apply(lambda x: round(x))

# %%
df_formateado["NumCompaniesWorked"].value_counts()
# Out:
# NumCompaniesWorked
# 1    546
# 0    213
# 3    175
# 2    159
# 4    151
# 7     79
# 6     75
# 5     66
# 8     55
# 9     54
# Name: count, dtype: int64

# %%
df_formateado.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# dtype: int64

# %%
dicc_inv={1 :'Low',
2 :'Medium',
3 :'High',
4 :'Very High'}

df_formateado["JobInvolvement"]=df_formateado["JobInvolvement"].map(dicc_inv)

# %%
def agrupar_rangos(valor):
    """
    Agrupa valores en rangos redondeando al entero más cercano.
    Por ejemplo:
    - Valores entre 1 y 1.5 se agrupan en 1.
    - Valores entre 1.6 y 2.5 se agrupan en 2.
    """
    if 1 <= valor < 1.5:
        return 'Low'
    elif 1.5 <= valor < 2.5:
        return 'Medium'
    elif 2.5 <= valor < 3.5:
        return 'High'
    elif 3.5 <= valor < 4.5:
        return 'Very High'
    else:
        return None  # Manejo de valores fuera del rango esperado
df_formateado['JobSatisfaction'] = df_formateado['JobSatisfaction'].apply(agrupar_rangos)

# %%
def agrupar_rangos(valor):
    """
    Agrupa valores en rangos redondeando al entero más cercano.
    Por ejemplo:
    - Valores entre 1 y 1.5 se agrupan en 1.
    - Valores entre 1.6 y 2.5 se agrupan en 2.
    """
    if 1 <= valor < 1.5:
        return 'Bad'
    elif 1.5 <= valor < 2.5:
        return 'Good'
    elif 2.5 <= valor < 3.5:
        return 'Better'
    elif 3.5 <= valor < 4.5:
        return 'Best'
    else:
        return None  
    
df_formateado['WorkLifeBalance'] = df_formateado['WorkLifeBalance'].apply(agrupar_rangos)

# %%
dicc_stock={0 :'Bad',
1 :'Good',
2 :'Better',
3 :'Best'}

df_formateado["StockOptionLevel"]=df_formateado["StockOptionLevel"].map(dicc_stock)

# %%
dicc_jlevel={1 :'Intern',
2 :'Junior',
3 :'Senior',
4 :'Manager',
5:'Head'}

df_formateado["JobLevel"]=df_formateado["JobLevel"].map(dicc_jlevel)

# %%
df_formateado.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 0  51.0        0.0      Travel_Rarely                   Sales
# 1  31.0        1.0  Travel_Frequently  Research & Development
# 2  32.0        0.0  Travel_Frequently  Research & Development
# 3  38.0        0.0         Non-Travel  Research & Development
# 4  32.0        0.0      Travel_Rarely  Research & Development
#
#   DistanceFromHome      Education EducationField  Gender JobLevel  \
# 0      entre 5 y 8        College  Life Sciences  Female   Intern
# 1     entre 9 y 12  Below College  Life Sciences  Female   Intern
# 2    entre 13 y 18         Master          Other    Male  Manager
# 3      entre 1 y 4         Doctor  Life Sciences    Male   Senior
# 4     entre 9 y 12  Below College        Medical    Male   Intern
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married       1482.108                   1
# 1         Research Scientist        Single        473.357                   0
# 2            Sales Executive       Married       2184.064                   1
# 3            Human Resources       Married        940.273                   3
# 4            Sales Executive        Single        264.646                   4
#
#    PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 0               11.0              Bad                  1
# 1               23.0             Good                  6
# 2               15.0             Best                  5
# 3               11.0             Best                 13
# 4               12.0           Better                  9
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                   6.0             1.0                      0.0
# 1                   3.0             5.0                      1.0
# 2                   2.0             5.0                      0.0
# 3                   5.0             8.0                      7.0
# 4                   2.0             6.0                      0.0
#
#    YearsWithCurrManager EnvironmentSatisfaction JobSatisfaction  \
# 0                   0.0                    High       Very High
# 1                   4.0                    High          Medium
# 2                   3.0                  Medium          Medium
# 3                   5.0               Very High       Very High
# 4                   4.0               Very High             Low
#
#   WorkLifeBalance JobInvolvement
# 0            Good           High
# 1            Best         Medium
# 2             Bad           High
# 3          Better         Medium
# 4          Better           High

# %% [markdown]
# ### **VISUALIZACION DISTRIBUCIONES**

# %%
visualizador=f.Visualizador(df_formateado)

# %% [markdown]
# ***Numéricas***

# %%
visualizador.plot_numericas(color="red", tamano_grafica=(20, 20))

# %% [markdown]
# Podemos observar en las distribuciones de las numéricas para que nos de una idea a la hora de cuáles podrían ser y cuales no normales

# %% [markdown]
# ***Categóricas***

# %%
visualizador.plot_categoricas(color="blue", tamano_grafica=(20, 30))

# %% [markdown]
# Podemos observar en las columnas categóricas que no parece haber diferencias exageradas o sospechosamente grandes entre una categoría y el resto con lo que no nos planteamos prescindir de ninguna.

# %%
visualizador.plot_relacion("Attrition", tamano_grafica=(20, 30), tamanio_fuente=18)

# %% [markdown]
# Podemos observar en la relación de cada columna con la variable dependiente como el NO (0.0) domina en todo debido al desbalanceo.

# %%
visualizador.deteccion_outliers(color = "pink")

# %% [markdown]
# Podemos observar los Outliers univariados en esta gráfica

# %%
visualizador.correlacion(tamano_grafica = (7, 5))

# %% [markdown]
# **Correlacion muy alta entre YearsAtCompany y YearsWithCurrManager me cargo ***YearsWithCurrManager*** .**

# %%
df_formateado.drop(columns="YearsWithCurrManager", inplace=True)

# %% [markdown]
# ### **DESBALANCEO**

# %%
round(df_crudo["Attrition"].value_counts(normalize=True)*100,2)
# Out:
# Attrition
# 0    83.98
# 1    16.02
# Name: proportion, dtype: float64

# %% [markdown]
# ##### Ahora que ya hemos terminado con esto pasamos la variable dependiente a numérica

# %% [markdown]
# ## EDA
#
# ### Estadísticos principales
# - No parace haber demasiada distorsión entre la media y la mediana de la mayoría de variables (Exceptuando MonthlyIncome y StockOptional aunque no es nada exagerado) lo que nos muestra que no parece haber muchos valores atípicos.
#
#
# #### Duplicados
# - No hay datos duplicados en la base de datos
# - Sin embargo al eliminar columnas entre ellas el EmployeeID se nos generan duplicados (Es raro que haya gente que comparta distancia, satisfacción, edad, puesto etc. Por ello se eliminan 2837 filas)
#
# #### Datos relevantes
# - Las columnas que se eliminan son Over18 y EmployeeCount, StandardHours, EmployeeID porque no aportan nada de información.
#
# - La columna YearsWithCurrManager   está muy correlacionada con YearsAtCompany asi que me cargo YearsWithCurrManager
#
# #### Nulos
# - Tenemos 5 columnas con nulos: NumCompaniesWorked ,EnvironmentSatisfaction ,JobSatisfaction ,WorkLifeBalance (las cuales imputo nulos y luego paso a categóricas) y TotalWorkingYears (la cual voy a mantener como numérica).
#
#
# #### Formateos
# - La variable dependiente la codificamos como 0 para la categoría No y 1 para la categoría Si
#
# - Variables como Jobsatisfaction, JobLevel, Education, PerformaceRate etc las paso a categóricas (un total de 11 columnas paso a categóricas) y en el caso concreto de DistanceFromHome agrupo en categorías  (Tras haber imputado sus nulos mientras eran numéricas).
#
# #### Outliers
# - Se detectan Outliers univariados en MonthlyIncome y todas las variables de Years
#
# #### Desbalanceo
# - Existe un Desvalanceo de 84% (No) frente a 16% (Si) que trataremos a la hora de separar nuestros datos en X e Y usando un SMOTENC, y un

# %% [markdown]
# ## FILTROS (LIMPIEZA INICIAL)

# %% [markdown]
# ***Observamos los outliers univariados en MonthlyIncome***

# %%
df_formateado[df_formateado["MonthlyIncome"] > 1830].head()
# Out:
#      Age  Attrition     BusinessTravel              Department  \
# 2   32.0        0.0  Travel_Frequently  Research & Development
# 26  26.0        0.0  Travel_Frequently  Research & Development
# 55  33.0        0.0  Travel_Frequently  Research & Development
# 56  39.0        0.0      Travel_Rarely                   Sales
# 73  27.0        0.0         Non-Travel  Research & Development
#
#    DistanceFromHome Education EducationField  Gender JobLevel  \
# 2     entre 13 y 18    Master          Other    Male  Manager
# 26     entre 9 y 12  Bachelor  Life Sciences  Female   Intern
# 55     entre 9 y 12  Bachelor  Life Sciences    Male  Manager
# 56      entre 1 y 4    Master  Life Sciences    Male   Intern
# 73      entre 1 y 4  Bachelor  Life Sciences    Male   Intern
#
#               JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 2     Sales Executive       Married       2184.064                   1
# 26            Manager       Married       1840.883                   1
# 55  Research Director       Married       2191.296                   6
# 56    Sales Executive       Married       2222.145                   1
# 73  Research Director       Married       1900.999                   0
#
#     PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 2                15.0             Best                  5
# 26               22.0              Bad                  5
# 55               12.0             Good                 12
# 56               22.0             Good                 21
# 73               17.0              Bad                  6
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 2                    2.0             5.0                      0.0
# 26                   3.0             5.0                      3.0
# 55                   3.0            10.0                      8.0
# 56                   6.0            21.0                     11.0
# 73                   3.0             5.0                      1.0
#
#    EnvironmentSatisfaction JobSatisfaction WorkLifeBalance JobInvolvement
# 2                   Medium          Medium             Bad           High
# 26                     Low             Low          Better           High
# 55               Very High          Medium          Better           High
# 56                    High             Low          Better           High
# 73                    High          Medium          Better           High

# %%
(df_formateado["MonthlyIncome"] > 1830).sum()
# Out:
# 131

# %% [markdown]
# <!-- ***Observamos los outliers univariados en TotalWorkingYears*** -->

# %%
# df_formateado[df_formateado["TotalWorkingYears"] > 28].head()

# %%
# (df_formateado["TotalWorkingYears"] > 28).sum()

# %% [markdown]
# ***Observamos los outliers univariados en YearsAtCompany***

# %%
df_formateado[df_formateado["YearsAtCompany"] >18].head()
# Out:
#      Age  Attrition     BusinessTravel              Department  \
# 10  45.0        0.0      Travel_Rarely  Research & Development
# 12  55.0        0.0      Travel_Rarely  Research & Development
# 23  42.0        0.0      Travel_Rarely  Research & Development
# 37  42.0        0.0  Travel_Frequently                   Sales
# 42  41.0        0.0      Travel_Rarely  Research & Development
#
#    DistanceFromHome      Education EducationField  Gender JobLevel  \
# 10    entre 13 y 18        College        Medical    Male   Junior
# 12    entre 13 y 18         Master  Life Sciences  Female   Intern
# 23      entre 1 y 4         Master  Life Sciences    Male   Intern
# 37      entre 1 y 4        College      Marketing    Male   Senior
# 42    entre 24 y 29  Below College  Life Sciences    Male   Intern
#
#                    JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 10   Laboratory Technician       Married        902.983                   0
# 12         Sales Executive        Single        625.794                   0
# 23  Manufacturing Director       Married       1008.638                   1
# 37       Research Director       Married        334.028                   5
# 42   Laboratory Technician        Single        268.827                   1
#
#     PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 10               13.0           Better                 21
# 12               17.0              Bad                 37
# 23               14.0              Bad                 12
# 37               13.0              Bad                 23
# 42               12.0              Bad                 22
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 10                   2.0            20.0                      4.0
# 12                   2.0            36.0                      4.0
# 23                   4.0            20.0                     11.0
# 37                   2.0            20.0                      4.0
# 42                   6.0            22.0                      0.0
#
#    EnvironmentSatisfaction JobSatisfaction WorkLifeBalance JobInvolvement
# 10                    High       Very High          Better         Medium
# 12               Very High             Low          Better           High
# 23                  Medium            High          Better            Low
# 37                    High          Medium            Best           High
# 42               Very High          Medium          Better           High

# %%
(df_formateado["YearsAtCompany"] > 18).sum()
# Out:
# 110

# %% [markdown]
# ***Observamos los outliers univariados en YearsSinceLastPromotion***

# %%
df_formateado[df_formateado["YearsSinceLastPromotion"] >7].head()
# Out:
#      Age  Attrition     BusinessTravel              Department  \
# 11  36.0        0.0      Travel_Rarely  Research & Development
# 13  47.0        1.0         Non-Travel  Research & Development
# 23  42.0        0.0      Travel_Rarely  Research & Development
# 53  45.0        0.0  Travel_Frequently  Research & Development
# 55  33.0        0.0  Travel_Frequently  Research & Development
#
#    DistanceFromHome      Education EducationField  Gender JobLevel  \
# 11    entre 24 y 29  Below College  Life Sciences    Male   Intern
# 13      entre 1 y 4  Below College        Medical    Male   Intern
# 23      entre 1 y 4         Master  Life Sciences    Male   Intern
# 53      entre 1 y 4  Below College        Medical  Female   Intern
# 55     entre 9 y 12       Bachelor  Life Sciences    Male  Manager
#
#                    JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 11   Laboratory Technician       Married        381.601                   0
# 13      Research Scientist       Married        651.106                   1
# 23  Manufacturing Director       Married       1008.638                   1
# 53         Sales Executive      Divorced        400.020                   1
# 55       Research Director       Married       2191.296                   6
#
#     PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 11               12.0           Better                 16
# 13               11.0           Better                 10
# 23               14.0              Bad                 12
# 53               13.0              Bad                 24
# 55               12.0             Good                 12
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 11                   2.0            15.0                     10.0
# 13                   4.0            10.0                      9.0
# 23                   4.0            20.0                     11.0
# 53                   6.0            24.0                      9.0
# 55                   3.0            10.0                      8.0
#
#    EnvironmentSatisfaction JobSatisfaction WorkLifeBalance JobInvolvement
# 11                    High       Very High          Better           High
# 13                     Low          Medium            Good         Medium
# 23                  Medium            High          Better            Low
# 53                     Low             Low          Better           High
# 55               Very High          Medium          Better           High

# %%
(df_formateado["YearsSinceLastPromotion"] > 7).sum()
# Out:
# 112

# %% [markdown]
# ***Observamos los outliers univariados en YearsWithCurrManager***   QUE NO HACE FALTA PORQUE LA HEMOS ELIMINADO

# %%
# df_formateado[df_formateado["YearsWithCurrManager"] >14]

# %%
# (df_formateado["YearsWithCurrManager"] > 14).sum()

# %%
df_formateado.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 0  51.0        0.0      Travel_Rarely                   Sales
# 1  31.0        1.0  Travel_Frequently  Research & Development
# 2  32.0        0.0  Travel_Frequently  Research & Development
# 3  38.0        0.0         Non-Travel  Research & Development
# 4  32.0        0.0      Travel_Rarely  Research & Development
#
#   DistanceFromHome      Education EducationField  Gender JobLevel  \
# 0      entre 5 y 8        College  Life Sciences  Female   Intern
# 1     entre 9 y 12  Below College  Life Sciences  Female   Intern
# 2    entre 13 y 18         Master          Other    Male  Manager
# 3      entre 1 y 4         Doctor  Life Sciences    Male   Senior
# 4     entre 9 y 12  Below College        Medical    Male   Intern
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married       1482.108                   1
# 1         Research Scientist        Single        473.357                   0
# 2            Sales Executive       Married       2184.064                   1
# 3            Human Resources       Married        940.273                   3
# 4            Sales Executive        Single        264.646                   4
#
#    PercentSalaryHike StockOptionLevel  TotalWorkingYears  \
# 0               11.0              Bad                  1
# 1               23.0             Good                  6
# 2               15.0             Best                  5
# 3               11.0             Best                 13
# 4               12.0           Better                  9
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                   6.0             1.0                      0.0
# 1                   3.0             5.0                      1.0
# 2                   2.0             5.0                      0.0
# 3                   5.0             8.0                      7.0
# 4                   2.0             6.0                      0.0
#
#   EnvironmentSatisfaction JobSatisfaction WorkLifeBalance JobInvolvement
# 0                    High       Very High            Good           High
# 1                    High          Medium            Best         Medium
# 2                  Medium          Medium             Bad           High
# 3               Very High       Very High          Better         Medium
# 4               Very High             Low          Better           High

# %% [markdown]
# Tras Observar los Outliers, nos hacemos una idea de cara al momento que los acabemos tratando

# %%
df_formateado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1573 non-null   float64
#  1   Attrition                1573 non-null   float64
#  2   BusinessTravel           1573 non-null   object
#  3   Department               1573 non-null   object
#  4   DistanceFromHome         1573 non-null   category
#  5   Education                1573 non-null   category
#  6   EducationField           1573 non-null   object
#  7   Gender                   1573 non-null   object
#  8   JobLevel                 1573 non-null   category
#  9   JobRole                  1573 non-null   object
#  10  MaritalStatus            1573 non-null   object
#  11  MonthlyIncome            1573 non-null   float64
#  12  NumCompaniesWorked       1573 non-null   int64
#  13  PercentSalaryHike        1573 non-null   float64
#  14  StockOptionLevel         1573 non-null   category
#  15  TotalWorkingYears        1573 non-null   int64
#  16  TrainingTimesLastYear    1573 non-null   category
#  17  YearsAtCompany           1573 non-null   float64
#  18  YearsSinceLastPromotion  1573 non-null   float64
#  19  EnvironmentSatisfaction  1573 non-null   object
#  20  JobSatisfaction          1573 non-null   object
#  21  WorkLifeBalance          1573 non-null   object
#  22  JobInvolvement           1573 non-null   category
# dtypes: category(6), float64(6), int64(2), object(9)
# memory usage: 219.6+ KB

# %%
df_formateado.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# dtype: int64

# %%
df_formateado.to_pickle("../../datos/datos2/datos_sin_nulos.pkl")
